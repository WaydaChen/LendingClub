# %%
#Essential imports
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns

# %%
data_dict = pd.read_csv('./LCDataDictionary_Categories_Alina_csv/LoanStats-Table 1.csv')
data_dict
# Out:
#     Categories by Alina            LoanStatNew  \
# 0                   NaN         acc_now_delinq
# 1                   NaN   acc_open_past_24mths
# 2                   NaN             addr_state
# 3                   NaN               all_util
# 4                   NaN             annual_inc
# ..                  ...                    ...
# 148                 NaN      settlement_amount
# 149                 NaN  settlement_percentage
# 150                 NaN        settlement_term
# 151                 NaN                    NaN
# 152                 NaN                    NaN
#
#                                            Description  Unnamed: 3  \
# 0    The number of accounts on which the borrower i...         NaN
# 1           Number of trades opened in past 24 months.         NaN
# 2    The state provided by the borrower in the loan...         NaN
# 3                Balance to credit limit on all trades         NaN
# ...

# %%
data_dict['Categories by Alina'].value_counts(dropna=False)
# Out:
# NaN                             89
# Fico at origination related     25
# Not available at origination    25
# Relevant                        12
# Not informative                  2
# Name: Categories by Alina, dtype: int64
